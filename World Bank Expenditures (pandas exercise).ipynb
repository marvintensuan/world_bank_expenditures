# %%
import pandas as pd

# %%
df = pd.read_csv('World_Bank_Expenditures_by_Organizational_Unit.csv')

# %%
df
# Out:
#                          Organizational Unit  \
# 0                        Governance services
# 1                          Operational units
# 2                     Institutional services
# 3    Centrally-managed accounts and programs
# 4                    Administrative services
# ..                                       ...
# 116             Reimbursements, fees, others
# 117  Centrally-managed accounts and programs
# 118                      Governance services
# 119                        Operational units
# 120              Total administrative budget
#
#                     Vice Presidential Unit or Grouping  Fiscal Year  \
# 0                                  Governance services         2009
# 1                              Operational units Total         2009
# 2                               Institutional services         2009
# 3              Centrally-managed accounts and programs         2009
# 4                              Administrative services         2009
# ...
